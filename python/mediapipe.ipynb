# %%
import os
import cv2
import time
import mediapipe as mp

cap = cv2.VideoCapture(0)

mpHands = mp.solutions.hands
hands = mpHands.Hands() #Default is already implemented.
mpDraw = mp.solutions.drawing_utils

cTime = 0
pTime = 0

while True:
    success, img = cap.read()

    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)

    if results.multi_hand_landmarks: #If hands are detected, phir...
        for handLmS in results.multi_hand_landmarks:
            for id, lm in enumerate(handLmS.landmark): # Getting ID number and landmark information.
                #print(id,lm )
                h, w, c = img.shape
                cx, cy = int(lm.x * w), int(lm.y * h)
                print(id, cx, cy)

                #if id == 0:
                #    cv2.circle((cx, cy), 20, (255, 0, 0), cv2.FILLED)


            mpDraw.draw_landmarks(img, handLmS, mpHands.HAND_CONNECTIONS)

    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime

    cv2.putText(img, str(int(fps)), (10,70), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 3, (25, 0, 255), 3)

    cv2.imshow("Image Frame", img)
    cv2.waitKey(1)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758343120.073265   11467 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1758343120.086718   13136 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-2), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.12.38+kali-amd64)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1758343120.109603   13114 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758343120.126350   13112 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/pisgah/dev/tests/vision/python/.venv/lib/python3.12/site-packages/cv2/qt/plugins"
# ...

# %%
import cv2
import mediapipe as mp
import time


mpPose = mp.solutions.pose
pose = mpPose.Pose()
mpDraw = mp.solutions.drawing_utils



cap = cv2.VideoCapture(0) # 0 is for webcam, add file name to read from file.
pTime = 0

while True:
    success, img = cap.read()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = pose.process(imgRGB)

    print(results.pose_landmarks)

    if results.pose_landmarks:
        mpDraw.draw_landmarks(img, results.pose_landmarks, mpPose.POSE_CONNECTIONS)
        for id, lm in enumerate(results.pose_landmarks.landmark):
            h, w, c = img.shape
            cx, cy = int(lm.x * w), int(lm.y * h)

    
    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime

    cv2.putText(img, str(int(fps)), (70,50), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0, 255), 3)

    cv2.imshow("Image", img)
    cv2.waitKey(1)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758342579.355812    5791 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1758342579.366112    5869 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-2), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.12.38+kali-amd64)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1758342579.428437    5843 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758342579.460045    5849 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...
